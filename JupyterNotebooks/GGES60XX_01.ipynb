# %%
# !pip install scitbx
# !pip install sciml

# %%
from scitbx.easy_import import *

# %%
pd.read_csv(r'https://github.com/soonyenju/scitbx/blob/master/scitbx/data/fluxnet_meta_212.csv?raw=true', index_col = 0)
# Out:
#        IGBP        LAT         LON                START                  END  \
# ID
# AR-SLu   MF -33.464800  -66.459800  2009-01-01 00:00:00  2011-12-31 23:30:00
# AR-Vir  ENF -28.239500  -56.188600  2009-01-01 00:00:00  2012-12-31 23:30:00
# AT-Neu  GRA  47.116670   11.317500  2002-01-01 00:00:00  2012-12-31 23:30:00
# AU-Ade  WSA -13.076900  131.117800  2007-01-01 00:00:00  2009-12-31 23:30:00
# AU-ASM  ENF -22.283000  133.249000  2010-01-01 00:00:00  2014-12-31 23:30:00
# ...     ...        ...         ...                  ...                  ...
# US-Wi9  ENF  46.618778  -91.081444  2004-01-01 00:00:00  2005-12-31 23:30:00
# US-Wkg  GRA  31.736500 -109.941900  2004-01-01 00:00:00  2014-12-31 23:30:00
# US-WPT  WET  41.464639  -82.996157  2011-01-01 00:00:00  2013-12-31 23:30:00
# ZA-Kru  SAV -25.019700   31.496900  2000-01-01 00:00:00  2013-12-31 23:30:00
# ZM-Mon  DBF -15.437780   23.252780  2000-01-01 00:00:00  2009-12-31 23:30:00
#
# ...

# %%
import notebook

dir(notebook.__spec__)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cached',
#  '_initializing',
#  '_set_fileattr',
#  '_uninitialized_submodules',
#  'cached',
#  'has_location',
#  'loader',
#  'loader_state',
#  'name',
#  'origin',
#  'parent',
#  'submodule_search_locations']

# %%
import requests

# example for students

# url = 'https://zenodo.org/records/14960129/files/VMPR_2020_LU.ZIP?download=1'
url = 'https://zenodo.org/records/8272103/files/PM25-20180106.nc?download=1'


r = requests.get(url, stream=True)
if r.status_code == 200:
  with open('test_delete.nc', 'wb') as f:
    for chunk in r.iter_content(1024):
      f.write(chunk)

# %%
# xr.open_dataset('test_delete.nc')['PM2.5'].plot()

# %% [markdown]
# # basic machine learning
#
# ![image.png](attachment:b2bfd8b0-521b-4d82-9fa0-b0c294e1f6ef.png)
# ![image.png](attachment:890fd69e-ed25-41cc-a4ba-a95252e35b29.png)

# %%
import sklearn

# %%
# !jupyter lab --generate-config
# Out:
# Writing default config to: C:\Users\sz2e24\.jupyter\jupyter_lab_config.py

# %%
# Out:
# WindowsPath('C:/Users/sz2e24')

# %%
p = Path.home().joinpath(r'.jupyter/jupyter_lab_config.py')

# %%
# # Open the file in read mode
# with open(p, 'r') as file:
#     # Read the contents of the file
#     file_contents = file.read()
# pprint(file_contents)

# %%
# load_tif()
